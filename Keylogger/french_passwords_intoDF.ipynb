# %% [markdown]
# ### Import Libraries ###

# %%
import pandas as pd

# %% [markdown]
# ### Load french passwords.txt file into a dataframe ###

# %%
# step 1 = file path

file_path = "/content/french_passwords_top20000.txt"

# step 2 = explore the data using with open(file_path) as f: readline()

doc=open(file_path,'r')
lines=doc.readlines()

print(lines)
# Out:
# ['f123456\n', '123456789\n', 'azerty\n', '1234561\n', 'qwerty\n', 'marseille\n', '000000\n', '1234567891\n', 'doudou\n', '12345\n', 'loulou\n', '123\n', 'password\n', 'azertyuiop\n', '12345678\n', 'soleil\n', 'chouchou\n', '1234\n', '1234567\n', '123123\n', '123451\n', 'bonjour\n', '111111\n', 'nicolas\n', 'jetaime\n', 'coucou\n', 'motdepasse\n', 'Status\n', 'julien\n', 'thomas\n', 'camille\n', '010203\n', 'chocolat\n', 'iloveyou\n', 'iloveyou1\n', 'portugal\n', '1234567890\n', 'alexandre\n', '654321\n', 'maxime\n', '00000\n', 'wxcvbn\n', 'oceane\n', 'pompier\n', '12345671\n', 'marine\n', '0000\n', 'maison\n', 'isabelle\n', 'celine\n', 'sandrine\n', 'pierre\n', 'caroline\n', 'elodie\n', 'olivier\n', 'mohamed\n', 'romain\n', 'badoo\n', 'football\n', 'princesse\n', 'nathalie\n', 'boubou\n', 'vincent\n', 'anthony\n', 'aurelie\n', 'caramel\n', 'dragon\n', 'sophie\n', 'amour\n', 'papillon\n', 'antoine\n', 'louloute\n', '0123456789\n', 'sebastien\n', 'audrey\n', '666666\n', 'emilie\n', 'na
# ...

# %%
#Cleaning passwords:

lst=[]
for i,passwd in enumerate(lines):
  lst.append(lines[i].strip('\n'))

print(lst)
# Out:
# ['f123456', '123456789', 'azerty', '1234561', 'qwerty', 'marseille', '000000', '1234567891', 'doudou', '12345', 'loulou', '123', 'password', 'azertyuiop', '12345678', 'soleil', 'chouchou', '1234', '1234567', '123123', '123451', 'bonjour', '111111', 'nicolas', 'jetaime', 'coucou', 'motdepasse', 'Status', 'julien', 'thomas', 'camille', '010203', 'chocolat', 'iloveyou', 'iloveyou1', 'portugal', '1234567890', 'alexandre', '654321', 'maxime', '00000', 'wxcvbn', 'oceane', 'pompier', '12345671', 'marine', '0000', 'maison', 'isabelle', 'celine', 'sandrine', 'pierre', 'caroline', 'elodie', 'olivier', 'mohamed', 'romain', 'badoo', 'football', 'princesse', 'nathalie', 'boubou', 'vincent', 'anthony', 'aurelie', 'caramel', 'dragon', 'sophie', 'amour', 'papillon', 'antoine', 'louloute', '0123456789', 'sebastien', 'audrey', '666666', 'emilie', 'naruto', 'france', '987654321', 'voiture', '789456', 'amandine', 'pauline', 'laurent', 'stephane', 'melanie', 'vanille', 'benjamin', 'chipie', 'valentin', '
# ...

# %%
# DataFrame construction from Dictionnary:

data={'passwords':lst }
pd.DataFrame(data=data)
